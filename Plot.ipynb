# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# data = {'Training Time': [1.05629,8.80186,57.18024,0.04351,398.65767,45.30024,30.99272],
#         'Testing Time': [0.02699,0.28985,0.01399,117.77564,58.33432,1.68212,1.77908]}

# df = pd.DataFrame(data,columns=['Training Time', 'Testing Time'], index = ['DT','RF','LR','KNN','KNN-DT-RF-LR','MLP (25,25)','MLP (50,50)'])
# fig = plt.figure()
# df.plot.bar()
# plt.xlabel('Models')
# plt.ylabel('Time')
# plt.title('Training Time vs Testing Time in different models')
# plt.savefig("Fig3.jpg",bbox_inches ="tight",pad_inches = 1)
# #plt.savefig("Fig3.png",bbox_inches ="tight",pad_inches = 1)
# plt.show()

# %%
# data = {"Accuracy":[99.82032,98.9475,99.02]}
# df = pd.DataFrame(data,columns=["Accuracy"], index = ['ML ENSEMBLE','DEEP ENSEMBLE','DL-IDS'])
# df.plot.bar()
# plt.subplots_adjust(hspace=1.0) 
# plt.xlabel('Models')
# plt.ylim(0,130)
# # plt.ylabel('V')
# plt.title('Accuracy Evaluation In Different Models')
# # plt.savefig("Fig7.jpg",bbox_inches ="tight",pad_inches = 5)
# plt.savefig("Fig_1.png",bbox_inches ="tight")
# plt.show()

data = {"Log Loss":[99.82032,98.9475,99.02]}
df = pd.DataFrame(data,columns=["Accuracy"], index = ['ML ENSEMBLE','DEEP ENSEMBLE','DL-IDS'])
df.plot.bar()
plt.subplots_adjust(hspace=1.0) 
plt.xlabel('Models')
plt.ylim(0,130)
# plt.ylabel('V')
plt.title('Accuracy Evaluation In Different Models')
# plt.savefig("Fig7.jpg",bbox_inches ="tight",pad_inches = 5)
plt.savefig("Fig_1.png",bbox_inches ="tight")
plt.show()

# %%
# data = {"Log Loss":[5.62467,0.12668,0.02687,0.25709,0.05057,0.00803]}
# df = pd.DataFrame(data,columns=["Log Loss"], index = ['NB','DT','RF','LR','KNN','KNN-NB-DT-RF'])
# df.plot(color=['orange'],marker='o',linestyle='dotted',linewidth=2)
# plt.subplots_adjust(hspace=1.0) 
# plt.xlabel('Models')
# # plt.ylabel('V')
# plt.title('Accuracy Evaluation In Different Models')
# # plt.savefig("Fig7.jpg",bbox_inches ="tight",pad_inches = 5)
# plt.savefig("Fig7.png",bbox_inches ="tight")
# plt.show()

# %%
data = {"MCC Score":[0.74772,0.74772,0.99729,0.89914,0.99475,0.99775],
        "Cohen's Kappa Score":[0.72434,0.72434,0.99728,0.89907,0.99474,0.99775]}

df = pd.DataFrame(data,columns=['MCC Score', "Cohen's Kappa Score"], index = ['NB','DT','RF','LR','KNN','KNN-NB-DT-RF'])
# df.plot(color=['red','cyan'],marker='o',linestyle='dotted',linewidth=2)
df.plot.bar(color=['green','cyan'])
plt.subplots_adjust(hspace=1.0) 
plt.xlabel('Models')
# plt.ylabel('V')
plt.title('Evaluation Metrices In Different ML Models II')
# plt.savefig("Fig6.jpg",bbox_inches ="tight",pad_inches = 5)
plt.savefig("Fig6.png",bbox_inches ="tight")
plt.show()

# %%
data = {"Precision":[83.93432,83.93432,99.78321,92.00978,99.58026,99.82042],
        "Recall":[77.93237,77.93237,99.78319,91.92640,99.57976,99.82032],
        "F1-Score":[76.07206,76.07206,99.78319,91.95403,99.57918,99.82034],
        "Accuracy":[77.93237,77.93237,99.78319,91.92640,99.57976,99.82032]}
df = pd.DataFrame(data,columns=["Precision","Recall","F1-Score","Accuracy"], index = ['NB','DT','RF','LR','KNN','KNN-NB-DT-RF'])
# df.plot(color=['orange','red','green','blue'],marker='o',linestyle='dotted',linewidth=2)
df.plot.bar()
plt.subplots_adjust(hspace=1.0) 
plt.xlabel('Models')
# plt.ylabel('V')
plt.title('Evaluation Metrices In Different ML Models I')
# plt.savefig("Fig5.jpg",bbox_inches ="tight",pad_inches = 5)
plt.savefig("Fig5.png",bbox_inches ="tight")
plt.show()

# %%
# # TRAINING TIME
# names = ['NB','DT','RF','LR','KNN','KNN-DT-RF-LR','MLP (50,50)','MLP (25,25)']
# values = [0.45802,1.05629,8.80186,57.18024,0.04351,398.65767,48.43656,93.3923]
# f = plt.figure(figsize =(40,3), num = 10)
# plt.subplot(131)
# plt.ylim(0,300)
# plt.bar(names, values,width=0.2)
